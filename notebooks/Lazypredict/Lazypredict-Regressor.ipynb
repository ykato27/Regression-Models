# %% [markdown]
# ## Lazypredict-Regressorのサンプルコード

# %%
# %load_ext lab_black

# %%
# ライブラリーのインポート
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

import lazypredict

# Lazypredict Regressor
from lazypredict.Supervised import LazyRegressor

# ボストンの住宅価格データ
from sklearn.datasets import load_boston

# 評価指標
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# 前処理
from sklearn.preprocessing import StandardScaler
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
print(lazypredict.__version__)
# Out:
# 0.2.9

# %%
# データセットの読込み
boston = load_boston()

# 説明変数の格納
df = pd.DataFrame(boston.data, columns=boston.feature_names)
# 目的変数の追加
df["MEDV"] = boston.target

# データの中身を確認
df.head()
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM   AGE  DIS  RAD    TAX  PTRATIO      B  \
# 0  0.01 18.00   2.31  0.00 0.54 6.58 65.20 4.09 1.00 296.00    15.30 396.90
# 1  0.03  0.00   7.07  0.00 0.47 6.42 78.90 4.97 2.00 242.00    17.80 396.90
# 2  0.03  0.00   7.07  0.00 0.47 7.18 61.10 4.97 2.00 242.00    17.80 392.83
# 3  0.03  0.00   2.18  0.00 0.46 7.00 45.80 6.06 3.00 222.00    18.70 394.63
# 4  0.07  0.00   2.18  0.00 0.46 7.15 54.20 6.06 3.00 222.00    18.70 396.90
#
#    LSTAT  MEDV
# 0   4.98 24.00
# 1   9.14 21.60
# 2   4.03 34.70
# 3   2.94 33.40
# 4   5.33 36.20

# %% [markdown]
# #### 前処理

# %%
# ランダムシード値
RANDOM_STATE = 10

# 学習データと評価データの割合
TEST_SIZE = 0.2

# 学習データと評価データを作成
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, 0 : df.shape[1] - 1],
    df.iloc[:, df.shape[1] - 1],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
)

# %%
# Lazy Predict（回帰）の設定と実行
reg = LazyRegressor(
    verbose=0,
    ignore_warnings=False,
    custom_metric=None,
    predictions=True,
    random_state=RANDOM_STATE,
)
models, predictions = reg.fit(x_train, x_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:04<00:00, 10.08it/s]

# %%
# 検証結果
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.87       0.88  3.49        0.31
# GradientBoostingRegressor                    0.86       0.88  3.52        0.20
# XGBRegressor                                 0.85       0.87  3.65        0.07
# RandomForestRegressor                        0.84       0.86  3.83        0.39
# LGBMRegressor                                0.82       0.85  4.00        0.05
# BaggingRegressor                             0.82       0.84  4.05        0.07
# HistGradientBoostingRegressor                0.81       0.84  4.13        0.51
# AdaBoostRegressor                            0.80       0.83  4.26        0.43
# PoissonRegressor                             0.73       0.77  4.94        0.04
# ExtraTreeRegressor                           0.72       0.76  5.01        0.02
# MLPRegressor                                 0.70       0.74  5.24        0.94
# DecisionTreeRegressor                        0.69       0.73  5.35        0.02
# KNeighborsRegressor                          0.63       0.67  5.84        0.02
# LassoLarsCV                                  0.62       0.67  5.85        0.06
# SGDRegressor                                 0.62       0.67  5.86        0.01
# LassoCV                                      0.62       0.67  5.86        0.13
# ElasticNetCV                                 0.62       0.67  5.86        0.09
# BayesianRidge                                0.62       0.67  5.86        0.02
# Ridge                                        0.62       0.67  5.86        0.02
# RidgeCV                                      0.62       0.67  5.86        0.01
# LassoLarsIC                                  0.62       0.67  5.87        0.03
# Lars                                         0.62       0.67  5.87        0.02
# TransformedTargetRegressor                   0.62       0.67  5.87        0.01
# LinearRegression                             0.62       0.67  5.87        0.02
# LarsCV                                       0.61       0.66  5.96        0.12
# HuberRegressor                               0.61       0.66  5.96        0.03
# OrthogonalMatchingPursuitCV                  0.61       0.66  6.00        0.02
# LinearSVR                                    0.58       0.64  6.16        0.03
# Lasso                                        0.55       0.61  6.40        0.04
# PassiveAggressiveRegressor                   0.55       0.61  6.41        0.01
# RANSACRegressor                              0.55       0.60  6.44        0.09
# ElasticNet                                   0.51       0.57  6.69        0.02
# SVR                                          0.49       0.55  6.83        0.03
# GammaRegressor                               0.49       0.55  6.84        0.03
# GeneralizedLinearRegressor                   0.49       0.55  6.85        0.03
# TweedieRegressor                             0.49       0.55  6.85        0.02
# NuSVR                                        0.47       0.54  6.96        0.05
# OrthogonalMatchingPursuit                    0.37       0.45  7.59        0.01
# GaussianProcessRegressor                    -0.01       0.12  9.59        0.05
# DummyRegressor                              -0.28      -0.11 10.79        0.02
# LassoLars                                   -0.28      -0.11 10.79        0.02
# KernelRidge                                 -4.97      -4.20 23.32        0.03

# %%
# 予測値
predictions
# Out:
#      AdaBoostRegressor  BaggingRegressor  BayesianRidge  \
# 0                23.22             24.69          30.67
# 1                30.27             29.16          31.70
# 2                28.97             25.68          30.74
# 3                26.68             29.46          22.80
# 4                20.82             20.26          18.97
# ..                 ...               ...            ...
# 97               20.29             21.27          22.48
# 98               22.30             21.14          26.55
# 99               22.50             21.23          23.24
# 100              22.89             22.74          23.92
# 101              22.17             18.49          19.69
#
#      DecisionTreeRegressor  DummyRegressor  ElasticNet  ElasticNetCV  \
# 0                    28.40           21.84       25.88         30.68
# 1                    28.00           21.84       29.49         31.71
# 2                    22.50           21.84       27.91         30.75
# 3                    24.80           21.84       27.21         22.76
# 4                    20.10           21.84       20.16         18.99
# ..                     ...             ...         ...           ...
# 97                   21.70           21.84       22.43         22.45
# 98                   18.90           21.84       23.62         26.55
# 99                   21.70           21.84       22.11         23.22
# 100                  22.30           21.84       24.92         23.90
# 101                  24.40           21.84       20.44         19.69
#
#      ExtraTreeRegressor  ExtraTreesRegressor  GammaRegressor  ...  \
# 0                 25.10                25.74           25.68  ...
# 1                 27.90                29.95           29.88  ...
# 2                 30.80                25.66           28.26  ...
# 3                 34.90                28.10           26.25  ...
# 4                 21.90                18.99           18.81  ...
# ..                  ...                  ...             ...  ...
# 97                22.40                21.69           22.97  ...
# 98                20.00                20.42           23.47  ...
# 99                23.60                20.05           21.30  ...
# 100               20.50                22.41           24.10  ...
# 101               23.60                20.20           19.31  ...
#
#      RANSACRegressor  RandomForestRegressor  Ridge  RidgeCV  SGDRegressor  \
# 0              30.52                  24.86  30.99    30.99         30.62
# 1              34.34                  29.53  31.72    31.72         31.76
# 2              28.65                  25.22  30.85    30.85         30.82
# 3              26.56                  28.89  22.40    22.40         22.86
# 4              13.17                  19.17  18.88    18.88         18.98
# ..               ...                    ...    ...      ...           ...
# 97             22.25                  21.50  22.43    22.43         22.48
# 98             23.86                  20.88  26.69    26.69         26.67
# 99             22.41                  20.43  23.21    23.21         23.46
# 100            24.99                  22.73  23.92    23.92         23.77
# 101            21.14                  19.32  19.63    19.63         19.90
#
#       SVR  TransformedTargetRegressor  TweedieRegressor  XGBRegressor  \
# 0   27.62                       31.08             26.57         27.00
# 1   29.61                       31.72             29.94         25.88
# 2   26.17                       30.87             28.54         25.91
# 3   26.11                       22.28             26.71         25.43
# 4   18.73                       18.86             19.55         19.12
# ..    ...                         ...               ...           ...
# 97  23.06                       22.42             23.65         22.54
# 98  22.29                       26.73             24.08         21.74
# 99  20.35                       23.20             22.20         19.94
# 100 23.09                       23.92             24.94         19.61
# 101 18.81                       19.61             20.29         20.57
#
#      LGBMRegressor
# 0            28.44
# 1            29.04
# 2            27.34
# 3            24.26
# 4            18.61
# ..             ...
# 97           22.09
# 98           21.25
# 99           18.73
# 100          20.71
# 101          18.70
#
# [102 rows x 42 columns]
