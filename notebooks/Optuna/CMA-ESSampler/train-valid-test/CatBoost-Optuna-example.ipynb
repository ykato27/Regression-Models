# %% [markdown]
# ## CatBoost-Optunaのサンプルコード（train, valid, test使用）

# %%
# %load_ext lab_black

# %%
# ライブラリーのインポート
import os

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# ボストンの住宅価格データ
from sklearn.datasets import load_boston

# 前処理
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# CatBoost
import catboost as cb
from catboost import CatBoost, Pool

# Optuna
import optuna
from optuna.samplers import CmaEsSampler

# 評価指標
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=pd.core.common.SettingWithCopyWarning)

# %%
print(cb.__version__)
# Out:
# 0.26

# %%
print(optuna.__version__)
# Out:
# 2.8.0

# %%
# データセットの読込み
boston = load_boston()

# 説明変数の格納
df = pd.DataFrame(boston.data, columns=boston.feature_names)
# 目的変数の追加
df["MEDV"] = boston.target

# データの中身を確認
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# #### 前処理

# %%
# ランダムシード値
RANDOM_STATE = 10

# 学習データと評価データの割合
TEST_SIZE = 0.2

# 学習データと評価データを作成
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, 0 : df.shape[1] - 1],
    df.iloc[:, df.shape[1] - 1],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
)

# trainのデータセットの2割をモデル学習時のバリデーションデータとして利用する
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=TEST_SIZE, random_state=RANDOM_STATE
)

# %%
def objective(trial):

    param = {
        "iterations": trial.suggest_int("iterations", 50, 300),
        "depth": trial.suggest_int("depth", 4, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
        "random_strength": trial.suggest_int("random_strength", 0, 100),
        "bagging_temperature": trial.suggest_loguniform(
            "bagging_temperature", 0.01, 100.00
        ),
        "od_type": trial.suggest_categorical("od_type", ["IncToDec", "Iter"]),
        "od_wait": trial.suggest_int("od_wait", 10, 50),
    }

    model = cb.CatBoostRegressor(**param)

    model.fit(
        x_train,
        y_train,
        eval_set=[(x_valid, y_valid)],
        early_stopping_rounds=100,
        verbose=False,
    )

    preds = model.predict(x_valid)
    mae = mean_absolute_error(y_valid, preds)

    return mae

# %%
# %%time
# optunaで最適値を見つける
# create_studyメソッドの引数"sampler"にサンプラーと乱数シードを指定
study = optuna.create_study(direction='minimize', sampler=CmaEsSampler(seed=RANDOM_STATE))
study.optimize(objective, n_trials=50)
# Out:
# [I 2021-07-08 06:36:21,829] A new study created in memory with name: no-name-813537b1-bb41-4745-ac5f-8c8c4fc977ba
# [I 2021-07-08 06:36:23,030] Trial 0 finished with value: 1.9714684778872467 and parameters: {'iterations': 243, 'depth': 4, 'learning_rate': 0.08629294202140579, 'random_strength': 75, 'bagging_temperature': 0.986343187233007, 'od_type': 'IncToDec', 'od_wait': 41}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:23,036] The parameter 'od_type' in trial#1 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:25,402] Trial 1 finished with value: 2.402267557615796 and parameters: {'iterations': 175, 'depth': 8, 'learning_rate': 0.028966079322940607, 'random_strength': 49, 'bagging_temperature': 0.7370362034389614, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:25,407] The parameter 'od_type' in trial#2 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:27,044] Trial 2 finished with value: 2.72270832175003 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.015613370417884475, 'random_strength': 50, 'bagging_temperature': 0.69024383280847, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:27,048] The parameter 'od_type' in trial#3 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:28,263] Trial 3 finished with value: 2.235652053581879 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.05470111775234296, 'random_strength': 50, 'bagging_temperature': 0.7758081335702709, 'od_type': 'Iter', 'od_wait': 31}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:28,267] The parameter 'od_type' in trial#4 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:29,462] Trial 4 finished with value: 2.3909170122298 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.03069307922035012, 'random_strength': 50, 'bagging_temperature': 1.2421993474408937, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:29,466] The parameter 'od_type' in trial#5 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:31,231] Trial 5 finished with value: 2.3471297394695805 and parameters: {'iterations': 175, 'depth': 8, 'learning_rate': 0.03235828463102615, 'random_strength': 50, 'bagging_temperature': 1.190495932869843, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:31,234] The parameter 'od_type' in trial#6 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:32,376] Trial 6 finished with value: 2.2549624889726636 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.051678840853704625, 'random_strength': 50, 'bagging_temperature': 0.5039679252875129, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:32,380] The parameter 'od_type' in trial#7 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:33,550] Trial 7 finished with value: 2.3234265636106426 and parameters: {'iterations': 174, 'depth': 7, 'learning_rate': 0.042976044935830626, 'random_strength': 50, 'bagging_temperature': 0.928447224832653, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:33,555] The parameter 'od_type' in trial#8 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:34,921] Trial 8 finished with value: 2.4354288715439933 and parameters: {'iterations': 174, 'depth': 7, 'learning_rate': 0.026127392446553644, 'random_strength': 50, 'bagging_temperature': 0.7302894477560489, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:34,923] The parameter 'od_type' in trial#9 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:36,102] Trial 9 finished with value: 2.4047708742223772 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.02868590328555137, 'random_strength': 50, 'bagging_temperature': 0.2806815622908689, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:36,108] The parameter 'od_type' in trial#10 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:37,224] Trial 10 finished with value: 2.305381281233523 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.04165747020035182, 'random_strength': 50, 'bagging_temperature': 0.5009830369921665, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:37,231] The parameter 'od_type' in trial#11 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:38,954] Trial 11 finished with value: 2.175357868798419 and parameters: {'iterations': 176, 'depth': 8, 'learning_rate': 0.058209200348192054, 'random_strength': 49, 'bagging_temperature': 0.8175718892565715, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:38,957] The parameter 'od_type' in trial#12 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:40,078] Trial 12 finished with value: 2.0667582312175097 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.08891606605346898, 'random_strength': 50, 'bagging_temperature': 2.476153564838683, 'od_type': 'IncToDec', 'od_wait': 31}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:40,082] The parameter 'od_type' in trial#13 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:41,315] Trial 13 finished with value: 2.181869296139333 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.06392201146607615, 'random_strength': 50, 'bagging_temperature': 0.43060721416532605, 'od_type': 'IncToDec', 'od_wait': 31}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:41,319] The parameter 'od_type' in trial#14 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:42,861] Trial 14 finished with value: 2.0289054310360797 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.09519013511489431, 'random_strength': 49, 'bagging_temperature': 0.857901012007788, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:42,864] The parameter 'od_type' in trial#15 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:44,161] Trial 15 finished with value: 2.0836973349718955 and parameters: {'iterations': 175, 'depth': 8, 'learning_rate': 0.07655610839437453, 'random_strength': 51, 'bagging_temperature': 1.1241672815047172, 'od_type': 'Iter', 'od_wait': 31}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:44,165] The parameter 'od_type' in trial#16 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:45,469] Trial 16 finished with value: 2.285198971990269 and parameters: {'iterations': 176, 'depth': 7, 'learning_rate': 0.04598413473706818, 'random_strength': 50, 'bagging_temperature': 0.4638158167539014, 'od_type': 'Iter', 'od_wait': 31}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:45,473] The parameter 'od_type' in trial#17 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:46,686] Trial 17 finished with value: 2.072717920783434 and parameters: {'iterations': 174, 'depth': 6, 'learning_rate': 0.07801004687739042, 'random_strength': 50, 'bagging_temperature': 0.5719955787413818, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:46,694] The parameter 'od_type' in trial#18 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:48,033] Trial 18 finished with value: 1.9986101686480255 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.09254110121972961, 'random_strength': 50, 'bagging_temperature': 0.7749878786410473, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 0 with value: 1.9714684778872467.
# [W 2021-07-08 06:36:48,038] The parameter 'od_type' in trial#19 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:49,352] Trial 19 finished with value: 1.9555245000563548 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.10814683351260264, 'random_strength': 49, 'bagging_temperature': 0.5142372951503803, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:49,358] The parameter 'od_type' in trial#20 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:50,378] Trial 20 finished with value: 2.479471730271551 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.024302940481602153, 'random_strength': 50, 'bagging_temperature': 0.8082933635322465, 'od_type': 'Iter', 'od_wait': 31}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:50,382] The parameter 'od_type' in trial#21 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:51,473] Trial 21 finished with value: 2.2046322228400848 and parameters: {'iterations': 174, 'depth': 7, 'learning_rate': 0.2723464954665254, 'random_strength': 50, 'bagging_temperature': 0.6025417928399762, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:51,476] The parameter 'od_type' in trial#22 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:52,364] Trial 22 finished with value: 2.324134247974464 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.043469209272607036, 'random_strength': 50, 'bagging_temperature': 0.44611198710648986, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:52,368] The parameter 'od_type' in trial#23 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:53,370] Trial 23 finished with value: 2.1934880965853862 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.18655081348497565, 'random_strength': 50, 'bagging_temperature': 1.3133661751806058, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:53,374] The parameter 'od_type' in trial#24 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:54,320] Trial 24 finished with value: 1.9828064985065093 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.11465786813220664, 'random_strength': 50, 'bagging_temperature': 1.08981374535616, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:54,323] The parameter 'od_type' in trial#25 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:55,619] Trial 25 finished with value: 2.1018446775718047 and parameters: {'iterations': 174, 'depth': 8, 'learning_rate': 0.07083757411993997, 'random_strength': 49, 'bagging_temperature': 0.8522132034582449, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 19 with value: 1.9555245000563548.
# [W 2021-07-08 06:36:55,623] The parameter 'od_type' in trial#26 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:56,761] Trial 26 finished with value: 1.8853427909809986 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.13067010288294736, 'random_strength': 50, 'bagging_temperature': 0.9120335759330601, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:36:56,766] The parameter 'od_type' in trial#27 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:57,768] Trial 27 finished with value: 2.2471300625321273 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.028220112804074722, 'random_strength': 49, 'bagging_temperature': 1.1023317119627232, 'od_type': 'Iter', 'od_wait': 31}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:36:57,774] The parameter 'od_type' in trial#28 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:58,744] Trial 28 finished with value: 1.9870238671383684 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.17078793039397794, 'random_strength': 50, 'bagging_temperature': 1.198753584634642, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:36:58,748] The parameter 'od_type' in trial#29 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:36:59,724] Trial 29 finished with value: 1.9680032006803259 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.1155192686867778, 'random_strength': 50, 'bagging_temperature': 2.131088943766636, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:36:59,727] The parameter 'od_type' in trial#30 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:00,837] Trial 30 finished with value: 2.0045769276292043 and parameters: {'iterations': 176, 'depth': 7, 'learning_rate': 0.1227622616808374, 'random_strength': 50, 'bagging_temperature': 1.0098924784476504, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:00,842] The parameter 'od_type' in trial#31 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:02,143] Trial 31 finished with value: 2.0361732087499624 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.08955655141664935, 'random_strength': 49, 'bagging_temperature': 0.597500356013914, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:02,146] The parameter 'od_type' in trial#32 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:03,168] Trial 32 finished with value: 1.9982965860913258 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.13707656343655003, 'random_strength': 50, 'bagging_temperature': 1.105505529821045, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:03,172] The parameter 'od_type' in trial#33 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:04,257] Trial 33 finished with value: 2.044581356277076 and parameters: {'iterations': 174, 'depth': 6, 'learning_rate': 0.07515432679149128, 'random_strength': 49, 'bagging_temperature': 0.7602136794681714, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:04,268] The parameter 'od_type' in trial#34 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:05,770] Trial 34 finished with value: 2.0554271617466053 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.22827635394642126, 'random_strength': 49, 'bagging_temperature': 0.5361074030472996, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:05,778] The parameter 'od_type' in trial#35 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:07,049] Trial 35 finished with value: 2.0838352999183756 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.0692371436044784, 'random_strength': 49, 'bagging_temperature': 1.3333000196652844, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:07,058] The parameter 'od_type' in trial#36 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:08,427] Trial 36 finished with value: 2.0533153180099304 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.197916446926664, 'random_strength': 50, 'bagging_temperature': 0.6851826544396845, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:08,437] The parameter 'od_type' in trial#37 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:09,903] Trial 37 finished with value: 2.058851535524326 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.21314476779771194, 'random_strength': 50, 'bagging_temperature': 2.180346778534612, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:09,911] The parameter 'od_type' in trial#38 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:11,698] Trial 38 finished with value: 1.919398755913093 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.10532667766335316, 'random_strength': 51, 'bagging_temperature': 3.6431357445354604, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:11,716] The parameter 'od_type' in trial#39 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:13,143] Trial 39 finished with value: 1.9464247475884742 and parameters: {'iterations': 176, 'depth': 6, 'learning_rate': 0.0964427549039791, 'random_strength': 50, 'bagging_temperature': 5.641766857429889, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:13,150] The parameter 'od_type' in trial#40 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:14,755] Trial 40 finished with value: 2.109704545867456 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.17432727147969634, 'random_strength': 50, 'bagging_temperature': 1.259277679511741, 'od_type': 'IncToDec', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:14,764] The parameter 'od_type' in trial#41 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:16,279] Trial 41 finished with value: 2.1295311104063783 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.17109053624010198, 'random_strength': 50, 'bagging_temperature': 0.5233390826987272, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:16,283] The parameter 'od_type' in trial#42 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:17,987] Trial 42 finished with value: 1.9558202601204542 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.10930852125018696, 'random_strength': 50, 'bagging_temperature': 2.209536524498337, 'od_type': 'IncToDec', 'od_wait': 31}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:17,993] The parameter 'od_type' in trial#43 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:19,494] Trial 43 finished with value: 1.9653703616434468 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.12339108956779751, 'random_strength': 51, 'bagging_temperature': 2.167245001389526, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:19,501] The parameter 'od_type' in trial#44 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:20,725] Trial 44 finished with value: 2.0447471870509117 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.08667172400447613, 'random_strength': 50, 'bagging_temperature': 6.1497208802873224, 'od_type': 'Iter', 'od_wait': 30}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:20,732] The parameter 'od_type' in trial#45 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:22,002] Trial 45 finished with value: 2.0694569910974274 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.18122593815759508, 'random_strength': 50, 'bagging_temperature': 0.9596009131103521, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:22,008] The parameter 'od_type' in trial#46 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:23,220] Trial 46 finished with value: 1.9449842196353524 and parameters: {'iterations': 175, 'depth': 6, 'learning_rate': 0.15701666832055183, 'random_strength': 51, 'bagging_temperature': 6.014687297955473, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:23,226] The parameter 'od_type' in trial#47 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:24,659] Trial 47 finished with value: 1.956976939397915 and parameters: {'iterations': 174, 'depth': 7, 'learning_rate': 0.112652802858877, 'random_strength': 51, 'bagging_temperature': 1.002589846685253, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:24,664] The parameter 'od_type' in trial#48 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:26,231] Trial 48 finished with value: 2.1392470620136135 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.07935173608277594, 'random_strength': 51, 'bagging_temperature': 2.516117579937503, 'od_type': 'Iter', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# [W 2021-07-08 06:37:26,239] The parameter 'od_type' in trial#49 is sampled independently by using `RandomSampler` instead of `CmaEsSampler` (optimization performance may be degraded). `CmaEsSampler` does not support dynamic search space or `CategoricalDistribution`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `CmaEsSampler`, if this independent sampling is intended behavior.
# [I 2021-07-08 06:37:27,824] Trial 49 finished with value: 2.0279777587033956 and parameters: {'iterations': 175, 'depth': 7, 'learning_rate': 0.11623998557071948, 'random_strength': 51, 'bagging_temperature': 3.800527617011921, 'od_type': 'IncToDec', 'od_wait': 29}. Best is trial 26 with value: 1.8853427909809986.
# CPU times: user 46 s, sys: 14.4 s, total: 1min
# Wall time: 1min 6s

# %%
best_params = study.best_params
best_params["random_state"] = RANDOM_STATE
best_params
# Out:
# {'iterations': 175,
#  'depth': 6,
#  'learning_rate': 0.13067010288294736,
#  'random_strength': 50,
#  'bagging_temperature': 0.9120335759330601,
#  'od_type': 'IncToDec',
#  'od_wait': 30,
#  'random_state': 10}

# %%
# チューニングしたハイパーパラメーターをフィット
optimised_model = cb.CatBoostRegressor(**(best_params))

optimised_model.fit(x_train, y_train)

# CatBoost推論
y_pred = optimised_model.predict(x_test)
# Out:
# 0:	learn: 8.8301258	total: 2.43ms	remaining: 422ms
# 1:	learn: 8.5327045	total: 5.12ms	remaining: 443ms
# 2:	learn: 8.2697181	total: 7.25ms	remaining: 416ms
# 3:	learn: 8.0616444	total: 9.64ms	remaining: 412ms
# 4:	learn: 7.8322588	total: 11.8ms	remaining: 400ms
# 5:	learn: 7.6807961	total: 14.6ms	remaining: 410ms
# 6:	learn: 7.4992949	total: 16.9ms	remaining: 406ms
# 7:	learn: 7.3574938	total: 25.7ms	remaining: 536ms
# 8:	learn: 7.2153343	total: 27.7ms	remaining: 510ms
# 9:	learn: 7.0755669	total: 29.7ms	remaining: 490ms
# 10:	learn: 6.7450340	total: 32.9ms	remaining: 490ms
# 11:	learn: 6.5124649	total: 35.2ms	remaining: 478ms
# 12:	learn: 6.4420287	total: 37.9ms	remaining: 472ms
# 13:	learn: 6.3740807	total: 40.8ms	remaining: 469ms
# 14:	learn: 6.3369836	total: 43.5ms	remaining: 464ms
# 15:	learn: 6.0935660	total: 45.8ms	remaining: 455ms
# 16:	learn: 5.9557708	total: 49.1ms	remaining: 456ms
# 17:	learn: 5.8544576	total: 51.6ms	remaining: 450ms
# 18:	learn: 5.8054721	total: 54.7ms	remaining: 449ms
# 19:	learn: 5.7025170	total: 57.4ms	remaining: 445ms
# 20:	learn: 5.6314428	total: 61.2ms	remaining: 448ms
# 21:	learn: 5.5403911	total: 63.9ms	remaining: 444ms
# 22:	learn: 5.5362903	total: 64.5ms	remaining: 426ms
# 23:	learn: 5.4133393	total: 65.4ms	remaining: 412ms
# 24:	learn: 5.2656660	total: 69.5ms	remaining: 417ms
# 25:	learn: 5.2167117	total: 71.4ms	remaining: 409ms
# 26:	learn: 5.0562798	total: 73.5ms	remaining: 403ms
# 27:	learn: 4.9441652	total: 77.7ms	remaining: 408ms
# 28:	learn: 4.8730187	total: 78.8ms	remaining: 397ms
# 29:	learn: 4.7680434	total: 80.3ms	remaining: 388ms
# 30:	learn: 4.7374733	total: 82ms	remaining: 381ms
# 31:	learn: 4.6671708	total: 83ms	remaining: 371ms
# 32:	learn: 4.5597685	total: 84.4ms	remaining: 363ms
# 33:	learn: 4.5342542	total: 85.8ms	remaining: 356ms
# 34:	learn: 4.4061338	total: 87.1ms	remaining: 348ms
# 35:	learn: 4.3812129	total: 88.8ms	remaining: 343ms
# 36:	learn: 4.3263261	total: 92.6ms	remaining: 345ms
# 37:	learn: 4.2356304	total: 94.1ms	remaining: 339ms
# 38:	learn: 4.2298655	total: 94.7ms	remaining: 330ms
# 138:	learn: 1.3738201	total: 387ms	remaining: 100ms
# 139:	learn: 1.3562438	total: 387ms	remaining: 96.8ms
# 140:	learn: 1.3464820	total: 388ms	remaining: 93.7ms
# 141:	learn: 1.3271929	total: 390ms	remaining: 90.6ms
# 142:	learn: 1.3120892	total: 391ms	remaining: 87.6ms
# 143:	learn: 1.3070325	total: 395ms	remaining: 85ms
# 144:	learn: 1.2996537	total: 397ms	remaining: 82.2ms
# 145:	learn: 1.2814077	total: 398ms	remaining: 79.1ms
# 146:	learn: 1.2727105	total: 400ms	remaining: 76.1ms
# 147:	learn: 1.2609948	total: 401ms	remaining: 73.1ms
# 148:	learn: 1.2457772	total: 402ms	remaining: 70.1ms
# 149:	learn: 1.2340242	total: 403ms	remaining: 67.1ms
# 150:	learn: 1.2209900	total: 404ms	remaining: 64.2ms
# 151:	learn: 1.2129310	total: 405ms	remaining: 61.3ms
# 152:	learn: 1.1985074	total: 406ms	remaining: 58.4ms
# 153:	learn: 1.1830714	total: 407ms	remaining: 55.5ms
# 154:	learn: 1.1723711	total: 408ms	remaining: 52.7ms
# 155:	learn: 1.1594137	total: 409ms	remaining: 49.9ms
# 156:	learn: 1.1516742	total: 411ms	remaining: 47.1ms
# 157:	learn: 1.1385368	total: 412ms	remaining: 44.3ms
# 158:	learn: 1.1251590	total: 413ms	remaining: 41.5ms
# 159:	learn: 1.1104728	total: 414ms	remaining: 38.8ms
# 160:	learn: 1.0973925	total: 415ms	remaining: 36.1ms
# 161:	learn: 1.0853629	total: 416ms	remaining: 33.4ms
# 162:	learn: 1.0723061	total: 418ms	remaining: 30.8ms
# 163:	learn: 1.0654624	total: 420ms	remaining: 28.2ms
# 164:	learn: 1.0558969	total: 422ms	remaining: 25.6ms
# 165:	learn: 1.0468792	total: 424ms	remaining: 23ms
# 166:	learn: 1.0329146	total: 432ms	remaining: 20.7ms
# 167:	learn: 1.0227398	total: 435ms	remaining: 18.1ms
# 168:	learn: 1.0110631	total: 439ms	remaining: 15.6ms
# 169:	learn: 1.0000270	total: 441ms	remaining: 13ms
# 170:	learn: 0.9897705	total: 442ms	remaining: 10.3ms
# 171:	learn: 0.9824140	total: 443ms	remaining: 7.72ms
# 172:	learn: 0.9710405	total: 445ms	remaining: 5.14ms
# 173:	learn: 0.9612921	total: 446ms	remaining: 2.56ms
# 174:	learn: 0.9535814	total: 448ms	remaining: 0us

# %%
# 評価
def calculate_scores(true, pred):
    """全ての評価指標を計算する

    Parameters
    ----------
    true (np.array)       : 実測値
    pred (np.array)       : 予測値

    Returns
    -------
    scores (pd.DataFrame) : 各評価指標を纏めた結果

    """
    scores = {}
    scores = pd.DataFrame(
        {
            "R2": r2_score(true, pred),
            "MAE": mean_absolute_error(true, pred),
            "MSE": mean_squared_error(true, pred),
            "RMSE": np.sqrt(mean_squared_error(true, pred)),
        },
        index=["scores"],
    )
    return scores

# %%
scores = calculate_scores(y_test, y_pred)
print(scores)
# Out:
#               R2     MAE        MSE      RMSE
# scores  0.860679  2.6623  14.570245  3.817099
